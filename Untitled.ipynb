# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from torchvision import datasets, transforms
from sklearn.cluster import AffinityPropagation
import torch
import torch.utils.data as data_utils

#загрузить набор данных MNIST
transform = transforms.Compose([
transforms.ToTensor(),
transforms.Normalize((0.1307,), (0.3081,))  #уменьшает влияние масштаба
])

mnist_data = datasets.MNIST('data', train=True, download=True, transform=transform)

#создать DataLoader для получения пакетов данных
#data_loader = torch.utils.data.DataLoader(mnist_data, batch_size=64, shuffle=True) #разбивает перед каждым пуском программы данные на пакеты размером 64 и перемешивает их
size = torch.arange(10000)
data_loader = data_utils.Subset(mnist_data, size)

#Получить все изображения в виде тензора
all_images = torch.cat([x[0].view(-1, 28*28) for x in data_loader], dim=0)

"""
#использовать алгоритм KMeans для кластеризации данных
kmeans = KMeans(n_clusters=10).fit(all_images)

#Получение прогнозируемых меток и кластерных центров
pred_labels = kmeans.predict(all_images)
cluster_centers = kmeans.cluster_centers_

#Рассчитайте скорректированный индекс RAND между прогнозируемыми метками и истинными метками
true_labels = torch.cat([x[1] for x in data_loader], dim=0).numpy()
ari = metrics.adjusted_rand_score(true_labels, pred_labels)

#Распечатайте скорректированный индекс RAND и центры кластеров
print("Adjusted Rand Index:", ari)
print("Cluster Centers:", cluster_centers)
"""




#использовать алгоритм sklearn.cluster.AffinityPropagation для кластеризации данных
#af = AffinityPropagation(preference=-50) #, affinity='euclidean')
#af.fit(all_images)  # fit - Обучаем модель на данных
af = AffinityPropagation(preference=-50, damping=0.5)

# прогнозируемых меток и кластерных центров
#af_predicated_labels = af.predict(all_images)
af_predicated_labels = af.fit_predict(all_images)
af_cluster_centers = af.cluster_centers_

#Рассчитайте скорректированный индекс RAND между прогнозируемыми метками и истинными метками
true_labels = torch.cat([x[1] for x in data_loader], dim=0).numpy()
af_ari = metrics.adjusted_rand_score(true_labels, af_predicated_labels)

#Распечатайте скорректированный индекс RAND и центры кластеров
print("AF  Adjusted Rand Index:", ari)
print("Cluster Centers:", af_cluster_centers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 51
#      47 af = AffinityPropagation(preference=-50, damping=0.5)
#      49 # прогнозируемых меток и кластерных центров
#      50 #af_predicated_labels = af.predict(all_images)
# ---> 51 af_predicated_labels = af.fit_predict(all_images)
#      52 af_cluster_centers = af.cluster_centers_
#      54 #Рассчитайте скорректированный индекс RAND между прогнозируемыми метками и истинными метками
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_affinity_propagation.py:582, in AffinityPropagation.fit_predict(self, X, y)
#     563 def fit_predict(self, X, y=None):
#     564     """Fit clustering from features/affinity matrix; return cluster labels.
#     565
#     566     Parameters
#    (...)
#     580         Cluster labels.
#     581     """
# --> 582     return super().fit_predict(X, y)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:753, in ClusterMixin.fit_predict(self, X, y)
#     735 """
#     736 Perform clustering on `X` and returns cluster labels.
#     737
#    (...)
#     749     Cluster labels.
#     750 """
#     751 # non-optimized default implementation; override when a better
#     752 # method is possible for a given clustering algorithm
# --> 753 self.fit(X)
#     754 return self.labels_
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_affinity_propagation.py:514, in AffinityPropagation.fit(self, X, y)
#     506 preference = np.array(preference, copy=False)
#     508 random_state = check_random_state(self.random_state)
#     510 (
#     511     self.cluster_centers_indices_,
#     512     self.labels_,
#     513     self.n_iter_,
# --> 514 ) = _affinity_propagation(
#     515     self.affinity_matrix_,
#     516     max_iter=self.max_iter,
#     517     convergence_iter=self.convergence_iter,
#     518     preference=preference,
#     519     damping=self.damping,
#     520     verbose=self.verbose,
#     521     return_n_iter=True,
#     522     random_state=random_state,
#     523 )
#     525 if self.affinity != "precomputed":
#     526     self.cluster_centers_ = X[self.cluster_centers_indices_].copy()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_affinity_propagation.py:91, in _affinity_propagation(S, preference, convergence_iter, max_iter, damping, verbose, return_n_iter, random_state)
#      88 for it in range(max_iter):
#      89     # tmp = A + S; compute responsibilities
#      90     np.add(A, S, tmp)
# ---> 91     I = np.argmax(tmp, axis=1)
#      92     Y = tmp[ind, I]  # np.max(A + S, axis=1)
#      93     tmp[ind, I] = -np.inf
#
# File <__array_function__ internals>:200, in argmax(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:1242, in argmax(a, axis, out, keepdims)
#    1155 """
#    1156 Returns the indices of the maximum values along an axis.
#    1157
#    (...)
#    1239 (2, 1, 4)
#    1240 """
#    1241 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1242 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from torchvision import datasets, transforms
from sklearn.cluster import AffinityPropagation
import torch
import torch.utils.data as data_utils

#загрузить набор данных MNIST
transform = transforms.Compose([
transforms.ToTensor(),
transforms.Normalize((0.1307,), (0.3081,))  #уменьшает влияние масштаба
])

mnist_data = datasets.MNIST('data', train=True, download=True, transform=transform)

#создать DataLoader для получения пакетов данных
#data_loader = torch.utils.data.DataLoader(mnist_data, batch_size=64, shuffle=True) #разбивает перед каждым пуском программы данные на пакеты размером 64 и перемешивает их
size = torch.arange(10000)
data_loader = data_utils.Subset(mnist_data, size)

#Получить все изображения в виде тензора
all_images = torch.cat([x[0].view(-1, 28*28) for x in data_loader], dim=0)

"""
#использовать алгоритм KMeans для кластеризации данных
kmeans = KMeans(n_clusters=10).fit(all_images)

#Получение прогнозируемых меток и кластерных центров
pred_labels = kmeans.predict(all_images)
cluster_centers = kmeans.cluster_centers_

#Рассчитайте скорректированный индекс RAND между прогнозируемыми метками и истинными метками
true_labels = torch.cat([x[1] for x in data_loader], dim=0).numpy()
ari = metrics.adjusted_rand_score(true_labels, pred_labels)

#Распечатайте скорректированный индекс RAND и центры кластеров
print("Adjusted Rand Index:", ari)
print("Cluster Centers:", cluster_centers)
"""




#использовать алгоритм sklearn.cluster.AffinityPropagation для кластеризации данных
af = AffinityPropagation(preference=-50) #, affinity='euclidean')
af.fit(all_images)  # fit - Обучаем модель на данных


# прогнозируемых меток и кластерных центров
af_predicated_labels = af.predict(all_images)
af_cluster_centers = af.cluster_centers_

#Рассчитайте скорректированный индекс RAND между прогнозируемыми метками и истинными метками
true_labels = torch.cat([x[1] for x in data_loader], dim=0).numpy()
af_ari = metrics.adjusted_rand_score(true_labels, af_predicated_labels)

#Распечатайте скорректированный индекс RAND и центры кластеров
print("AF  Adjusted Rand Index:", ari)
print("Cluster Centers:", af_cluster_centers)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 46
#      44 #использовать алгоритм sklearn.cluster.AffinityPropagation для кластеризации данных
#      45 af = AffinityPropagation(preference=-50) #, affinity='euclidean')
# ---> 46 af.fit(all_images)  # fit - Обучаем модель на данных
#      49 # прогнозируемых меток и кластерных центров
#      50 af_predicated_labels = af.predict(all_images)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_affinity_propagation.py:494, in AffinityPropagation.fit(self, X, y)
#     492     self.affinity_matrix_ = X.copy() if self.copy else X
#     493 else:  # self.affinity == "euclidean"
# --> 494     self.affinity_matrix_ = -euclidean_distances(X, squared=True)
#     496 if self.affinity_matrix_.shape[0] != self.affinity_matrix_.shape[1]:
#     497     raise ValueError(
#     498         "The matrix of similarities must be a square array. "
#     499         f"Got {self.affinity_matrix_.shape} instead."
#     500     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\pairwise.py:328, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     322     if Y_norm_squared.shape != (1, Y.shape[0]):
#     323         raise ValueError(
#     324             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     325             f"Y_norm_squared of shape {original_shape}."
#     326         )
# --> 328 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\pairwise.py:366, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     361         YY = row_norms(Y, squared=True)[np.newaxis, :]
#     363 if X.dtype == np.float32:
#     364     # To minimize precision issues with float32, we compute the distance
#     365     # matrix on chunks of X and Y upcast to float64
# --> 366     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     367 else:
#     368     # if dtype is already float64, no need to chunk and upcast
#     369     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\pairwise.py:568, in _euclidean_distances_upcast(X, XX, Y, YY, batch_size)
#     565 else:
#     566     YY_chunk = YY[:, y_slice]
# --> 568 d = -2 * safe_sparse_dot(X_chunk, Y_chunk.T, dense_output=True)
#     569 d += XX_chunk
#     570 d += YY_chunk
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\extmath.py:192, in safe_sparse_dot(a, b, dense_output)
#     188 else:
#     189     ret = a @ b
#     191 if (
# --> 192     sparse.issparse(a)
#     193     and sparse.issparse(b)
#     194     and dense_output
#     195     and hasattr(ret, "toarray")
#     196 ):
#     197     return ret.toarray()
#     198 return ret
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\sparse\_base.py:1301, in isspmatrix(x)
#    1297         else:
#    1298             return np.zeros(self.shape, dtype=self.dtype, order=order)
# -> 1301 def isspmatrix(x):
#    1302     """Is x of a sparse matrix type?
#    1303
#    1304     Parameters
#    (...)
#    1326     False
#    1327     """
#    1328     return isinstance(x, spmatrix)
#
# KeyboardInterrupt:

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from torchvision import datasets, transforms
from sklearn.cluster import AffinityPropagation
import torch
import torch.utils.data as data_utils

#загрузить набор данных MNIST
transform = transforms.Compose([
transforms.ToTensor(),
transforms.Normalize((0.1307,), (0.3081,))  #уменьшает влияние масштаба
])

mnist_data = datasets.MNIST('data', train=True, download=True, transform=transform)

#создать DataLoader для получения пакетов данных
data_loader = torch.utils.data.DataLoader(mnist_data, batch_size=64, shuffle=True) #разбивает перед каждым пуском программы данные на пакеты размером 64 и перемешивает их
#size = torch.arange(10000)
#data_loader = data_utils.Subset(mnist_data, size)

#Получить все изображения в виде тензора
all_images = torch.cat([x[0].view(-1, 28*28) for x in data_loader], dim=0)

"""
#использовать алгоритм KMeans для кластеризации данных
kmeans = KMeans(n_clusters=10).fit(all_images)

#Получение прогнозируемых меток и кластерных центров
pred_labels = kmeans.predict(all_images)
cluster_centers = kmeans.cluster_centers_

#Рассчитайте скорректированный индекс RAND между прогнозируемыми метками и истинными метками
true_labels = torch.cat([x[1] for x in data_loader], dim=0).numpy()
ari = metrics.adjusted_rand_score(true_labels, pred_labels)

#Распечатайте скорректированный индекс RAND и центры кластеров
print("Adjusted Rand Index:", ari)
print("Cluster Centers:", cluster_centers)
"""




#использовать алгоритм sklearn.cluster.AffinityPropagation для кластеризации данных
af = AffinityPropagation(preference=-50) #, affinity='euclidean')
af.fit(all_images)  # fit - Обучаем модель на данных


# прогнозируемых меток и кластерных центров
af_predicated_labels = af.predict(all_images)
af_cluster_centers = af.cluster_centers_

#Рассчитайте скорректированный индекс RAND между прогнозируемыми метками и истинными метками
true_labels = torch.cat([x[1] for x in data_loader], dim=0).numpy()
af_ari = metrics.adjusted_rand_score(true_labels, af_predicated_labels)

#Распечатайте скорректированный индекс RAND и центры кластеров
print("AF  Adjusted Rand Index:", ari)
print("Cluster Centers:", af_cluster_centers)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 46
#      44 #использовать алгоритм sklearn.cluster.AffinityPropagation для кластеризации данных
#      45 af = AffinityPropagation(preference=-50) #, affinity='euclidean')
# ---> 46 af.fit(all_images)  # fit - Обучаем модель на данных
#      49 # прогнозируемых меток и кластерных центров
#      50 af_predicated_labels = af.predict(all_images)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_affinity_propagation.py:494, in AffinityPropagation.fit(self, X, y)
#     492     self.affinity_matrix_ = X.copy() if self.copy else X
#     493 else:  # self.affinity == "euclidean"
# --> 494     self.affinity_matrix_ = -euclidean_distances(X, squared=True)
#     496 if self.affinity_matrix_.shape[0] != self.affinity_matrix_.shape[1]:
#     497     raise ValueError(
#     498         "The matrix of similarities must be a square array. "
#     499         f"Got {self.affinity_matrix_.shape} instead."
#     500     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\pairwise.py:328, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     322     if Y_norm_squared.shape != (1, Y.shape[0]):
#     323         raise ValueError(
#     324             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     325             f"Y_norm_squared of shape {original_shape}."
#     326         )
# --> 328 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\pairwise.py:366, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     361         YY = row_norms(Y, squared=True)[np.newaxis, :]
#     363 if X.dtype == np.float32:
#     364     # To minimize precision issues with float32, we compute the distance
#     365     # matrix on chunks of X and Y upcast to float64
# --> 366     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     367 else:
#     368     # if dtype is already float64, no need to chunk and upcast
#     369     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\pairwise.py:568, in _euclidean_distances_upcast(X, XX, Y, YY, batch_size)
#     565 else:
#     566     YY_chunk = YY[:, y_slice]
# --> 568 d = -2 * safe_sparse_dot(X_chunk, Y_chunk.T, dense_output=True)
#     569 d += XX_chunk
#     570 d += YY_chunk
#
# MemoryError: Unable to allocate 2.54 GiB for an array with shape (18451, 18451) and data type float64
